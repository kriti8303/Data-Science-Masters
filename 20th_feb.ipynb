# %% [markdown]
# ## Assignment Question 1:
#
# GET Method : The get method is used to request the server to GET the data or information. It should not be used with the requesting sensitive data,
# and there are certain limits to the requesting data.
#
# POST Method : The post method is used to send the data to the server.

# %% [markdown]
# ## Assignment Question 2:
#
# The Request used in flask is an object that contains all the data sent from the Client to server. This data can be recovered using GET/POST method.

# %% [markdown]
# ## Assignment Question 3:
#
# Flask class has a redirect() function. When called, it returns a response object and redirects the user to another target
# location with specified status code.

# %% [markdown]
# ## Assignment Question 4:
#
# Templates are files that contain static data as well as placeholders for dynamic data. A template is rendered with specific data to produce a final document. Flask uses the jinja template library to render templates.

# %% [markdown]
# ## Assignment Question 5:

# %% [markdown]
# ![Screenshot%20%288%29.png](attachment:Screenshot%20%288%29.png)
