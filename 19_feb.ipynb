# %% [markdown]
# ## Assignment Question 1:
#
# Flask is a web framework. Flask allows you to build a web application by providing tools, libraries and technologies. This web application will be a web page, a wiki or a big web-based calender application or commercial website.
#
# Advantage of flask framework:
# 1. Integrated support for unit testing.
# 2. Built in development server and fast debugger.
# 3. Restful request dispatching.
# 4. Unicode base
# 5. Support for cookies

# %% [markdown]
# ## Assignment Question 2:

# %% [markdown]
# ![Screenshot%20%282%29.png](attachment:Screenshot%20%282%29.png)

# %% [markdown]
# ## Assignment Question 3:
#
# Routing (also known as request routing or URL dispatching) is mapping URLs to code that handles them.
#
# App routing means mapping the URLs to a specific function that will handle the logic for the URL. Modern web frameworks use more meaningful URLs to help users remember the URLs to help users remember the URLs and make nevigation simpler.

# %% [markdown]
# ## Assignment Question 4:

# %% [markdown]
# #### welcome message
# ![Screenshot%20%283%29.png](attachment:Screenshot%20%283%29.png)

# %% [markdown]
# #### company details :
# ![Screenshot%20%285%29.png](attachment:Screenshot%20%285%29.png)

# %% [markdown]
# ## Assignment Question 5:
#
# The url_for() function is used to build a URL to the specific function dynamically. The first argument is the name of the
# specified function, and then we can pass any number of keyword argument corresponding to the variable part of the URL.

# %%
from flask import Flask
from flask import request

# %%
app = Flask(__name__)

# %%
@app.route('/input_url')
def request_input():
    data = request.args.get('x')
    return "This is my input from url {}".format(data)
